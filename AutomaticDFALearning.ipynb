// %% [markdown]
// # Automatic DFA Learning

// %% [markdown]
// *April 2018 PMC@ISCAS*
//
// ---

// %% [markdown]
// ![logo](http://iscasmc.ios.ac.cn/roll/lib/exe/fetch.php?media=wiki:logo.png)

// %% [markdown]
// This is a tutorial and demonstration of our Java Library [```Regular Omega Language Learning (ROLL)```](http://iscasmc.ios.ac.cn/roll/doku.php) in a Groovy kernel Jupyter Notebook.You do not need to worry if you use Java and not familiar with Groovy. Because the syntax of these two languages are similar.
//
// In this notebook you will see
// - how to create a DFA as a learning target
// - how to configure a learning process
// - how to print the intermediate hypothesis and learner data structure in this hyper text environment
//
// You can run this tutorial step by step, or you can run your code and see what will happend.
//
// **Tips** : If something goes strange, just use the menu bar above ```Kernel -> Restart & Clear Output``` to rebot this notebook.
//
// ---

// %% [markdown]
// **First we load our compiled single fat jar.**

// %%
%classpath add jar ROLL.jar
// Out:
// Added jar: [ROLL.jar]

// %% [markdown]
// **Then we creat a target DFA on alphabet $\{a, b\}$ accepting $\{s \mid b \text{ occurs } 4 n + 3 \text{ times in } s \text{ (} n \ge 0 \text{)} \}$**

// %%
import roll.words.Alphabet
import roll.automata.DFA
import roll.automata.State

alphabet = new Alphabet();
alphabet.addLetter((char)'a');
alphabet.addLetter((char)'b');

// create an NBA with alphabet
target = new DFA(alphabet);
State fst = target.createState();
State snd = target.createState();
State thd = target.createState();
State fth = target.createState();


fst.addTransition(alphabet.indexOf((char)'a'), fst)
fst.addTransition(alphabet.indexOf((char)'b'), snd)
snd.addTransition(alphabet.indexOf((char)'a'), snd)
snd.addTransition(alphabet.indexOf((char)'b'), thd)
thd.addTransition(alphabet.indexOf((char)'a'), thd)
thd.addTransition(alphabet.indexOf((char)'b'), fth)
fth.addTransition(alphabet.indexOf((char)'a'), fth)
fth.addTransition(alphabet.indexOf((char)'b'), fst)

target.setInitial(fst)
target.setFinal(fth)

target
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="120pt" height="383pt" viewBox="0.00 0.00 120.21 383.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 379)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-379 116.214,-379 116.214,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="70" cy="-284" rx="18" ry="18"/><text text-anchor="middle" x="70" y="-279.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M87.0373,-290.379C96.8579,-291.681 106,-289.555 106,-284 106,-280.528 102.429,-278.396 97.3529,-277.602"/><polygon fill="black" stroke="black" points="97.031,-274.103 87.0373,-277.621 97.0435,-281.103 97.031,-274.103"/><text text-anchor="middle" x="109.107" y="-279.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="18" cy="-198" rx="18" ry="18"/><text text-anchor="middle" x="18" y="-193.8" font-family="Times,serif" font-size="14.00">1</text></g><!-- 0&#45;&gt;1 --><g id="edge2" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M60.9423,-268.368C53.0867,-255.678 41.5762,-237.085 32.4492,-222.341"/><polygon fill="black" stroke="black" points="35.3679,-220.406 27.1284,-213.746 29.416,-224.091 35.3679,-220.406"/><text text-anchor="middle" x="51.5" y="-236.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;1 --><g id="edge3" class="edge"><title>1&#45;&gt;1</title><path fill="none" stroke="black" d="M34.6641,-205.383C44.625,-207.023 54,-204.562 54,-198 54,-193.796 50.1525,-191.275 44.7682,-190.438"/><polygon fill="black" stroke="black" points="44.6002,-186.94 34.6641,-190.617 44.7247,-193.939 44.6002,-186.94"/><text text-anchor="middle" x="57.1069" y="-193.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><ellipse fill="none" stroke="black" cx="18" cy="-112" rx="18" ry="18"/><text text-anchor="middle" x="18" y="-107.8" font-family="Times,serif" font-size="14.00">2</text></g><!-- 1&#45;&gt;2 --><g id="edge4" class="edge"><title>1&#45;&gt;2</title><path fill="none" stroke="black" d="M18,-179.595C18,-168.257 18,-153.227 18,-140.315"/><polygon fill="black" stroke="black" points="21.5001,-140.095 18,-130.095 14.5001,-140.095 21.5001,-140.095"/><text text-anchor="middle" x="21.5" y="-150.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 2&#45;&gt;2 --><g id="edge5" class="edge"><title>2&#45;&gt;2</title><path fill="none" stroke="black" d="M34.6641,-119.383C44.625,-121.023 54,-118.562 54,-112 54,-107.796 50.1525,-105.275 44.7682,-104.438"/><polygon fill="black" stroke="black" points="44.6002,-100.94 34.6641,-104.617 44.7247,-107.939 44.6002,-100.94"/><text text-anchor="middle" x="57.1069" y="-107.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><ellipse fill="none" stroke="black" cx="65" cy="-22" rx="18" ry="18"/><ellipse fill="none" stroke="black" cx="65" cy="-22" rx="22" ry="22"/><text text-anchor="middle" x="65" y="-17.8" font-family="Times,serif" font-size="14.00">3</text></g><!-- 2&#45;&gt;3 --><g id="edge6" class="edge"><title>2&#45;&gt;3</title><path fill="none" stroke="black" d="M26.1868,-95.6716C32.7454,-83.3915 42.1228,-65.834 50.0171,-51.0531"/><polygon fill="black" stroke="black" points="53.3223,-52.2939 54.9462,-41.8242 47.1478,-48.9961 53.3223,-52.2939"/><text text-anchor="middle" x="46.5" y="-64.8" font-family="Times,serif" font-size="14.00">b</text></g><!- ...

// %% [markdown]
// **Second we create an ```Options``` object to configure the learning process**
//
// For DFA we have 3 kinds of algorithm and 2 kinds data structure. But there are only 4 valid composition.
//
// |                              | Options.Structure.TREE | Options.Structure.TABLE |
// |:----------------------------:|:----------------------:|:-----------------------:|
// | Options.Algorithm.DFA_LSTAR  | ✖️                     | ✔️                      |
// | Options.Algorithm.DFA_KV     | ✔️                     | ✖️                      |
// | Options.Algorithm.DFA_COLUMN | ✔️                     | ✔️                      |
//
// Here we use a table based column algorithm as a demonstration.

// %%
import roll.main.Options  

options = new Options();
options.algorithm = Options.Algorithm.DFA_COLUMN;
options.structure = Options.Structure.TABLE;

options
// Out:
// LEARNING,TABLE,DFA_COLUMN,NONE,NBA,UNDER,verbose=false,bs=false,dot=false,inputfile=null,outputfile=null,outputA=null,outputB=null

// %% [markdown]
// **Then we start a Learning process**
//
// ```LearningSequence.ceList(target,options)``` takes two arguments. ```target``` is the target DFA we created which will be used as membership and equivalence oracle. ```options``` configures wichi type of learning algorithm will be used. And it returns an ```ImmutableList<QuerySimple>``` object contains all the counter examples used in the whole Automatic learning process.

// %%
import roll.main.*
celist = LearningSequence.ceList(target,options)
// Out:
// [bbb:ϵ, bbb:ϵ]

// %%
celist.get(0);
// Out:
// $bbb$

// %%
celist.get(1);
// Out:
// $bbb$

// %%
System.out.println(celist.getClass())
celist.size()
// Out:
// class com.google.common.collect.RegularImmutableList
// 2

// %% [markdown]
// There we can see that the table based column algorithm use two counter example to achieve the target DFA. Coincidentally, the two counter examples are both $bbb$.
//
// And we can use ```LearningSequence.refinedLearner(target,options,celist)``` to get the intermediate learner object. Then we will see intermediate hypothesis and learner data.
//
// ```LearningSequence.refinedLearner(target,options,celist)``` returns the learner refined by all the counter examples in ```celist```

// %%
import roll.main.*
finalLearner = LearningSequence.refinedLearner(target,options,celist)
System.out.println(finalLearner.getClass())
finalLearner
// Out:
// class roll.learner.dfa.table.LearnerDFATableColumn
//      || ϵ | bb | b |
// ====================
// ϵ    || - | -  | - |
// b    || - | +  | - |
// bb   || - | -  | + |
// bbb  || + | -  | - |
// ====================
// a    || - | -  | - |
// ba   || - | +  | - |
// bba  || - | -  | + |
// bbba || + | -  | - |
// bbbb || - | -  | - |

// %% [markdown]
// Now we can see the table used by the algorithm. For example, $b$ and $bb$ are in different equivalence class because the correspond rows are different.
//
// ```Learner::getHypothesis``` returns the current hypothesis DFA of a Learner.

// %%
import roll.main.*
LearningSequence.refinedLearner(target,options,celist.subList(0,0)).getHypothesis()
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="102pt" height="117pt" viewBox="0.00 0.00 102.00 117.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 113)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-113 98,-113 98,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="orangered" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.7817,-21.2357C54.3149,-21.7856 63,-20.707 63,-18 63,-16.3504 59.7749,-15.3055 55.0981,-14.8653"/><polygon fill="black" stroke="black" points="54.8156,-11.3625 44.7817,-14.7643 54.7469,-18.3621 54.8156,-11.3625"/><text text-anchor="middle" x="66.1069" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 0&#45;&gt;0 --><g id="edge2" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.4203,-23.3159C61.791,-26.3462 81,-24.5742 81,-18 81,-12.7098 68.5617,-10.5292 54.652,-11.4581"/><polygon fill="black" stroke="black" points="53.9328,-8.01918 44.4203,-12.6841 54.7657,-14.9695 53.9328,-8.01918"/><text text-anchor="middle" x="84.5" y="-13.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1 --><g id="node2" class="node"><title>1</title></g><!-- 1&#45;&gt;0 --><g id="edge3" class="edge"><title>1&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-72.8129C27,-64.7895 27,-55.0475 27,-46.0691"/><polygon fill="black" stroke="black" points="30.5001,-46.0288 27,-36.0288 23.5001,-46.0289 30.5001,-46.0288"/></g></g></svg>

// %%
import roll.main.*
LearningSequence.refinedLearner(target,options,celist.subList(0,1)).getHypothesis()
// Out:
// <table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
//   <tr>
//     <th> Previous Hypothesis</th>
//     <th> Current Hypothesis </th>
//   </tr>
//   <tr>
//     <td><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="102pt" height="117pt" viewBox="0.00 0.00 102.00 117.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 113)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-113 98,-113 98,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="orangered" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.7817,-21.2357C54.3149,-21.7856 63,-20.707 63,-18 63,-16.3504 59.7749,-15.3055 55.0981,-14.8653"/><polygon fill="black" stroke="black" points="54.8156,-11.3625 44.7817,-14.7643 54.7469,-18.3621 54.8156,-11.3625"/><text text-anchor="middle" x="66.1069" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 0&#45;&gt;0 --><g id="edge2" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.4203,-23.3159C61.791,-26.3462 81,-24.5742 81,-18 81,-12.7098 68.5617,-10.5292 54.652,-11.4581"/><polygon fill="black" stroke="black" points="53.9328,-8.01918 44.4203,-12.6841 54.7657,-14.9695 53.9328,-8.01918"/><text text-anchor="middle" x="84.5" y="-13.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1 --><g id="node2" class="node"><title>1</title></g><!-- 1&#45;&gt;0 --><g id="edge3" class="edge"><title>1&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-72.8129C27,-64.7895 27,-55.0475 27,-46.0691"/><polygon fill="black" stroke="black" points="30.5001,-46.0288 27,-36.0288 23.5001,-46.0289 30.5001,-46.0288"/></g></g></svg></td>
//     <td><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="77pt" height="203pt" viewBox="0.00 0.00 77.21 203.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 199)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-199 73.2139,-199 73.2139,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="orangered" stroke="black" cx="27" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-99.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.0373,-110.379C53.8579,-111.681 63,-109.555 63,-104 63,-100.528 59.4289,-98.3958 54.3529,-97.6025"/><polygon fill="black" stroke="black" points="54.031,-94.1029 44.0373,-97.6208 54.0435,-101.103 54.031,-94.1029"/><text text-anchor="middle" x="66.1069" y="-99.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="skyblue" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">1</text></g><!-- 0&#45;&gt;1 --><g id="edge2" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M20.3664,-87.2577C18.201,-81.3321 16.0772,-74.4629 15,-68 13.7131,-60.2787 14.7874,-51.9764 16.7311,-44.4398"/><polygon fill="black" stroke="black" points="20.1128,-45.3534 19.7803,-34.7638 13.4364,-43.2495 20.1128,-45.3534"/><text text-anchor="middle" x="18.5" y="-56.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;0 --><g id="edge4" class="edge"><title>1&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-36.0952C27,-47.3652 27,-62.3804 27,-75.3304"/><polygon fill="black" stroke="black" points="23.5001,-75.5951 27,-85.5951 30.5001,-75.5952 23.5001,-75.5951"/><text text-anchor="middle" x="30.5" y="-56.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;1 --><g id="edge3" class="edge"><title>1&#45;&gt;1</title><path fill="none" stroke="black" d="M43.6641,-25.3828C53.625,-27.0234 63,-24.5625 63,-18 63,-13.7959 59.1525,-11.2751 53.7682,-10.4375"/><polygon fill="black" stroke="black" points="53.6002,-6.93988 43.6641,-10.6172 53.7247,-13.9388 53.6002,-6.93988"/><text text-anchor="middle" x="66.1069" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 2 --><g id="node3" class="node"><title>2</title></g><!-- 2&#45;&gt;0 --><g id="edge5" class="edge"><title>2&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-158.813C27,-150.789 27,-141.047 27,-132.069"/><polygon fill="black" stroke="black" points="30.5001,-132.029 27,-122.029 23.5001,-132.029 30.5001,-132.029"/></g></g></svg></td>
//   </tr>
// </table>

// %% [markdown]
// We also show the preivous hypothesis DFA every time a Hypothesis is depicted on screen. **And the blue state was splited from the red one.**

// %%
import roll.main.*
LearningSequence.refinedLearner(target,options,celist.subList(0,2)).getHypothesis()
// Out:
// <table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
//   <tr>
//     <th> Previous Hypothesis</th>
//     <th> Current Hypothesis </th>
//   </tr>
//   <tr>
//     <td><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="77pt" height="203pt" viewBox="0.00 0.00 77.21 203.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 199)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-199 73.2139,-199 73.2139,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="orangered" stroke="black" cx="27" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-99.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.0373,-110.379C53.8579,-111.681 63,-109.555 63,-104 63,-100.528 59.4289,-98.3958 54.3529,-97.6025"/><polygon fill="black" stroke="black" points="54.031,-94.1029 44.0373,-97.6208 54.0435,-101.103 54.031,-94.1029"/><text text-anchor="middle" x="66.1069" y="-99.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">1</text></g><!-- 0&#45;&gt;1 --><g id="edge2" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M20.3664,-87.2577C18.201,-81.3321 16.0772,-74.4629 15,-68 13.7131,-60.2787 14.7874,-51.9764 16.7311,-44.4398"/><polygon fill="black" stroke="black" points="20.1128,-45.3534 19.7803,-34.7638 13.4364,-43.2495 20.1128,-45.3534"/><text text-anchor="middle" x="18.5" y="-56.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;0 --><g id="edge4" class="edge"><title>1&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-36.0952C27,-47.3652 27,-62.3804 27,-75.3304"/><polygon fill="black" stroke="black" points="23.5001,-75.5951 27,-85.5951 30.5001,-75.5952 23.5001,-75.5951"/><text text-anchor="middle" x="30.5" y="-56.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;1 --><g id="edge3" class="edge"><title>1&#45;&gt;1</title><path fill="none" stroke="black" d="M43.6641,-25.3828C53.625,-27.0234 63,-24.5625 63,-18 63,-13.7959 59.1525,-11.2751 53.7682,-10.4375"/><polygon fill="black" stroke="black" points="53.6002,-6.93988 43.6641,-10.6172 53.7247,-13.9388 53.6002,-6.93988"/><text text-anchor="middle" x="66.1069" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 2 --><g id="node3" class="node"><title>2</title></g><!-- 2&#45;&gt;0 --><g id="edge5" class="edge"><title>2&#45;&gt;0</title><path fill="none" stroke="black" d="M27,-158.813C27,-150.789 27,-141.047 27,-132.069"/><polygon fill="black" stroke="black" points="30.5001,-132.029 27,-122.029 23.5001,-132.029 30.5001,-132.029"/></g></g></svg></td>
//     <td><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="120pt" height="383pt" viewBox="0.00 0.00 120.21 383.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 379)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-379 116.214,-379 116.214,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="orangered" stroke="black" cx="70" cy="-284" rx="18" ry="18"/><text text-anchor="middle" x="70" y="-279.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M87.0373,-290.379C96.8579,-291.681 106,-289.555 106,-284 106,-280.528 102.429,-278.396 97.3529,-277.602"/><polygon fill="black" stroke="black" points="97.031,-274.103 87.0373,-277.621 97.0435,-281.103 97.031,-274.103"/><text text-anchor="middle" x="109.107" y="-279.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="18" cy="-198" rx="18" ry="18"/><text text-anchor="middle" x="18" y="-193.8" font-family="Times,serif" font-size="14.00">1</text></g><!-- 0&#45;&gt;1 --><g id="edge2" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M60.9423,-268.368C53.0867,-255.678 41.5762,-237.085 32.4492,-222.341"/><polygon fill="black" stroke="black" points="35.3679,-220.406 27.1284,-213.746 29.416,-224.091 35.3679,-220.406"/><text text-anchor="middle" x="51.5" y="-236.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;1 --><g id="edge3" class="edge"><title>1&#45;&gt;1</title><path fill="none" stroke="black" d="M34.6641,-205.383C44.625,-207.023 54,-204.562 54,-198 54,-193.796 50.1525,-191.275 44.7682,-190.438"/><polygon fill="black" stroke="black" points="44.6002,-186.94 34.6641,-190.617 44.7247,-193.939 44.6002,-186.94"/><text text-anchor="middle" x="57.1069" y="-193.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><ellipse fill="skyblue" stroke="black" cx="18" cy="-112" rx="18" ry="18"/><text text-anchor="middle" x="18" y="-107.8" font-family="Times,serif" font-size="14.00">2</text></g><!-- 1&#45;&gt;2 --><g id="edge4" class="edge"><title>1&#45;&gt;2</title><path fill="none" stroke="black" d="M18,-179.595C18,-168.257 18,-153.227 18,-140.315"/><polygon fill="black" stroke="black" points="21.5001,-140.095 18,-130.095 14.5001,-140.095 21.5001,-140.095"/><text text-anchor="middle" x="21.5" y="-150.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 2&#45;&gt;2 --><g id="edge5" class="edge"><title>2&#45;&gt;2</title><path fill="none" stroke="black" d="M34.6641,-119.383C44.625,-121.023 54,-118.562 54,-112 54,-107.796 50.1525,-105.275 44.7682,-104.438"/><polygon fill="black" stroke="black" points="44.6002,-100.94 34.6641,-104.617 44.7247,-107.939 44.6002,-100.94"/><text text-anchor="middle" x="57.1069" y="-107.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><ellipse fill="none" stroke="black" cx="65" cy="-22" rx="18" ry="18"/><ellipse fill="none" stroke="black" cx="65" cy="-22" rx="22" ry="22"/><text text-anchor="middle" x="65" y="-17.8" font-family="Times,serif" font-size="14.00">3</text></g><!-- 2&#45;&gt;3 --><g id="edge6" class="edge"><title>2&#45;&gt;3</title><path fill="none" stroke="black" d="M26.1868,-95.6716C32.7454,-83.3915 42.1228,-65.834 50.0171,-51.0531"/><polygon fill="black" stroke="black" points="53.3223,-52.2939 54.9462,-41.8242 47.1478,-48.9961 53.3223,-52.2939"/><text text-anchor="middle" x="46.5" y="-64.8" font-family="Times,serif" font-size="14.00" ...
