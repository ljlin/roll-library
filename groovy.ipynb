// %%
%classpath add jar /Users/lijianlin/Projects/roll-library-github/ROLL.jar
// Out:
// Added jar: [ROLL.jar]

// %%
import roll.main.ROLL
import roll.words.Alphabet
import roll.automata.NBA

alphabet = new Alphabet();
Character a = 'a';
Character b = 'b';

alphabet.addLetter(a);
alphabet.addLetter(b);
// create an NBA with alphabet
target = new NBA(alphabet);
target.createState();
target.createState();
target.createState();
int fst = 0, snd = 1, thd = 2;
target.getState(fst).addTransition(alphabet.indexOf(a), snd);
target.getState(fst).addTransition(alphabet.indexOf(a), thd);
target.getState(snd).addTransition(alphabet.indexOf(a), snd);
target.getState(thd).addTransition(alphabet.indexOf(b), thd);
target.setInitial(fst);
target.setFinal(snd);
target.setFinal(thd);
List<String> list = ["a", "b"];
target.toString();
target
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="164pt" height="211pt" viewBox="0.00 0.00 164.00 211.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 207)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-207 160,-207 160,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="51" cy="-112" rx="18" ry="18"/><text text-anchor="middle" x="51" y="-107.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="22" cy="-22" rx="18" ry="18"/><ellipse fill="none" stroke="black" cx="22" cy="-22" rx="22" ry="22"/><text text-anchor=
// ...

// %%
import roll.main.*
import roll.oracle.nba.rabit.*
import roll.main.ROLL
import roll.words.Alphabet
import roll.automata.NBA
import roll.parser.*;
    

options = new Options();
// options.inputFile = "/Users/lijianlin/Projects/roll-library-github/nba.hoa";
// options.format = Format.HOA;
// use the under-approximation method to construct a BA from an FDFA
options.approximation = Options.Approximation.UNDER;
// set NBA learner, here we use tree-based syntactic FDFA learner
options.algorithm = Options.Algorithm.SYNTACTIC;
options.structure = Options.Structure.TREE;
options

// Parser parser = UtilParser.prepare(options, options.inputFile , options.format);
// nba = parser.parse()
// teacher = new TeacherNBARABIT(options, target);
// Out:
// LEARNING,TREE,SYNTACTIC,NONE,NBA,UNDER,verbose=false,bs=false,dot=false,inputfile=null,outputfile=null,outputA=null,outputB=null

// %%
import roll.main.*
H = LearningSequence.ceList(target,options)
// Out:
// [a:a, a:b, a:a, a:b, b:a, a:a, a:b, a:baa, a:baa, a:baaaa, ab:a, a:a, a:b, aaa:b, a:a, a:b]

// %%
H.get(0);
// Out:
// $a(a)^\omega$

// %%
H.get(1);
// Out:
// $a(b)^\omega$

// %%
H.get(2);
// Out:
// $a(a)^\omega$

// %%
H.size()
// Out:
// 16

// %%
import roll.main.*
Learner = LearningSequence.refinedLearner(target,options,H)
// Out:
// <p> Leading Learner :  </p> <br> <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="294pt" height="356pt" viewBox="0.00 0.00 294.00 355.92" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 351.921)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-351.921 290,-351.921 290,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="146" cy="-315.423" rx="32.497" ry="32.497"/><text text-anchor="middle" x="146" y="-312.74" font-family="Times,serif" font-size="14.00">(ϵ, b)</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="103" cy="-210.649" rx="36.0516" ry="36.0516"/><text
// ...

// %%
import roll.main.*
Learner = LearningSequence.refinedLearner(target,options,H.subList(0,0)).getHypothesis()
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="103pt" height="117pt" viewBox="0.00 0.00 103.00 117.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 113)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-113 99,-113 99,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.7817,-21.2357C54.3149,-21.7856 63,-20.707 63,-18 63,-16.3504 59.7749,-15.3055 55.0981,-14.8653"/><poly
// ...

// %%
prefix = alphabet.getWordFromString("a")
// Out:
// 0

// %%
suffix = alphabet.getWordFromString("baa")
// Out:
// 1.0.0

// %%
import roll.query.*
cenew = new QuerySimple(prefix,suffix)
// Out:
// $a(baa)^\omega$

// %%
import roll.query.CE
cenew1 = CE.withAlphabet(alphabet).omega("a","baaa")
// Out:
// $a(baaa)^\omega$

// %%
import roll.query.CE
cenew2 = CE.withAlphabet(alphabet).finite("abaabaaa")
// Out:
// $abaabaaa$

// %%
import com.google.common.collect.ImmutableList;
celist2 = ImmutableList.builder().addAll(H.subList(0,7)).add(cenew).build()
// Out:
// [a:a, a:b, a:a, a:b, b:a, a:a, a:b, a:baa]

// %%
import roll.main.*
Learner = LearningSequence.refinedLearner(target,options,celist2).getHypothesis()
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="417pt" height="565pt" viewBox="0.00 0.00 416.63 564.90" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 560.901)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-560.901 412.626,-560.901 412.626,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="122" cy="-465.901" rx="18" ry="18"/><text text-anchor="middle" x="122" y="-461.701" font-family="Times,serif" font-size="14.00">0</text></g><!-- 3 --><g id="node2" class="node"><title>3</title><ellipse fill="none" stroke="black" cx="18" cy="-379.901" rx="18" ry="18"/><text text-anchor="middle" x="18" y="-375.701" font-fam
// ...

// %%
// arraylist = new ArrayList(H.subList(0,3))
arraylist = new ArrayList()
arraylist.add(cenew1)
arraylist.add(CE.withAlphabet(alphabet).omega("a","aabbaaa"))
arraylist.add(CE.withAlphabet(alphabet).omega("abb","aabbaaa"))
arraylist
// Out:
// [a:a, a:b, a:a, a:baaa]

// %%
import roll.main.*
Learner = LearningSequence.refinedLearner(target,options,arraylist).getHypothesis()
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="168pt" height="383pt" viewBox="0.00 0.00 168.04 383.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 379)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-379 164.04,-379 164.04,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="55.0401" cy="-284" rx="18" ry="18"/><text text-anchor="middle" x="55.0401" y="-279.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M72.0774,-290.379C81.898,-291.681 91.0401,-289.555 91.0401,-284 91.0401,-280.528 87.46
// ...

// %%
import roll.main.*
LL = LearningSequence.creat(target,options)

// %%
a = LL.next()

// %%
HTML("""
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg>
<br>
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg>
<br>
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg>
<br>
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="206pt" height="130pt" viewBox="0.00 0.00 206.00 130.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 126)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-126 202,-126 202,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="99" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="99" y="-101.044" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><polygon fill="lightgrey" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 0&#45;&gt;1 --><g id="edge1" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M85.871,-91.5579C78.612,-84.97 69.6152,-76.3607 62.3311,-68 56.0919,-60.8387 49.8455,-52.612 44.3778,-44.97"/><polygon fill="black" stroke="black" points="46.9618,-42.5573 38.3641,-36.3662 41.2244,-46.5676 46.9618,-42.5573"/><text text-anchor="middle" x="79.3345" y="-56.8" font-family="Times,serif" font-size="14.00">(3, A)</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><polygon fill="none" stroke="black" points="126,-36 72,-36 72,-0 126,-0 126,-36"/><text text-anchor="middle" x="99" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 0&#45;&gt;2 --><g id="edge2" class="edge"><title>0&#45;&gt;2</title><path fill="none" stroke="black" d="M99,-85.5951C99,-74.2572 99,-59.2271 99,-46.3153"/><polygon fill="black" stroke="black" points="102.5,-46.0951 99,-36.0952 95.5001,-46.0952 102.5,-46.0951"/><text text-anchor="middle" x="115.331" y="-56.8" font-family="Times,serif" font-size="14.00">(3, B)</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><polygon fill="none" stroke="black" points="198,-36 144,-36 144,-0 198,-0 198,-36"/><text text-anchor="middle" x="171" y="-13.8" font-family="Times,serif" font-size="14.00">ba</text></g><!-- 0&#45;&gt;3 --><g id="edge3" class="edge"><title>0&#45;&gt;3</title><path fill="none" stroke="black" d="M112.272,-91.5884C119.604,-85.0101 128.681,-76.4002 136,-68 142.219,-60.8617 148.418,-52.6417 153.833,-44.9987"/><polygon fill="black" stroke="black" points="156.976,-46.607 159.784,-36.3909 151.218,-42.6264 156.976,-46.607"/><text text-anchor="middle" x="163.331" y="-56.8" font-family="Times,serif" font-size="14.00">(2, C)</text></g></g></svg>
<br>
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="206pt" height="130pt" viewBox="0.00 0.00 206.00 130.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 126)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-126 202,-126 202,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="99" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="99" y="-101.044" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><polygon fill="lightgrey" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 0&#45;&gt;1 --><g id="edge1" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M85.871,-91.5579C78.612,-84.97 69.6152,-76.3607 62.3311,-68 56.0919,-60.8387 49.8455,-52.612 44.3778,-44.97"/><polygon fill="black" stroke="black" points="46.9618,-42.5573 38.3641,-36.3662 41.2244,-46.5676 46.9618,-42.5573"/><text text-anchor="middle" x="79.3345" y="-56.8" font-family="Times,serif" font-size="14.00">(4, A)</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><polygon fill="none" stroke="black" points="126,-36 72,-36 72,-0 126,-0 126,-36"/><text text-anchor="middle" x="99" y="-13.8" font-family="Times,serif" font-size="14.00">ab</text></g><!-- 0&#45;&gt;2 --><g id="edge2" class="edge"><title>0&#45;&gt;2</title><path fill="none" stroke="black" d="M99,-85.5951C99,-74.2572 99,-59.2271 99,-46.3153"/><polygon fill="black" stroke="black" points="102.5,-46.0951 99,-36.0952 95.5001,-46.0952 102.5,-46.0951"/><text text-anchor="middle" x="115.331" y="-56.8" font-family="Times,serif" font-size="14.00">(2, C)</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><polygon fill="none" stroke="black" points="198,-36 144,-36 144,-0 198,-0 198,-36"/><text text-anchor="middle" x="171" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 0&#45;&gt;3 --><g id="edge3" class="edge"><title>0&#45;&gt;3</title><path fill="none" stroke="black" d="M112.272,-91.5884C119.604,-85.0101 128.681,-76.4002 136,-68 142.219,-60.8617 148.418,-52.6417 153.833,-44.9987"/><polygon fill="black" stroke="black" points="156.976,-46.607 159.784,-36.3909 151.218,-42.6264 156.976,-46.607"/><text text-anchor="middle" x="163.331" y="-56.8" font-family="Times,serif" font-size="14.00">(4, B)</text></g></g></svg>
<br>
<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="294pt" height="356pt" viewBox="0.00 0.00 294.00 355.92" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 351.921)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-351.921 290,-351.921 290,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="146" cy="-315.423" rx="32.497" ry="32.497"/><text text-anchor="middle" x="146" y="-312.74" font-family="Times,serif" font-size="14.00">(ϵ, b)</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><ellipse fill="none" stroke="black" cx="103" cy="-210.649" rx="36.0516" ry="36.0516"/><text text-anchor="middle" x="103" y="-207.967" font-family="Times,serif" font-size="14.00">(ϵ, aa)</text></g><!-- 0&#45;&gt;1 --><g id="edge1" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" stroke-dasharray="5,2" d="M133.793,-285.247C129.725,-275.524 125.107,-264.487 120.708,-253.973"/><polygon fill="black" stroke="black" points="123.84,-252.39 116.751,-244.516 117.382,-255.092 123.84,-252.39"/></g><!-- 6 --><g id="node7" class="node"><title>6</title><ellipse fill="none" stroke="black" cx="189" cy="-210.649" rx="32.389" ry="32.389"/><text text-anchor="middle" x="189" y="-206.449" font-family="Times,serif" font-size="14.00">(a, aa)</text></g><!-- 0&#45;&gt;6 --><g id="edge6" class="edge"><title>0&#45;&gt;6</title><path fill="none" stroke="black" d="M158.207,-285.247C162.785,-274.305 168.059,-261.7 172.934,-250.048"/><polygon fill="black" stroke="black" points="176.28,-251.118 176.911,-240.542 169.823,-248.417 176.28,-251.118"/></g><!-- 2 --><g id="node3" class="node"><title>2</title><polygon fill="none" stroke="black" points="54,-123.187 0,-123.187 0,-87.1871 54,-87.1871 54,-123.187"/><text text-anchor="middle" x="27" y="-100.987" font-family="Times,serif" font-size="14.00">b</text></g><!-- 1&#45;&gt;2 --><g id="edge2" class="edge"><title>1&#45;&gt;2</title><path fill="none" stroke="black" stroke-dasharray="5,2" d="M81.8298,-180.829C70.4479,-165.335 56.5417,-146.404 45.5822,-131.484"/><polygon fill="black" stroke="black" points="48.2522,-129.206 39.5113,-123.219 42.6106,-133.351 48.2522,-129.206"/></g><!-- 3 --><g id="node4" class="node"><title>3</title><ellipse fill="none" stroke="black" cx="105" cy="-105.187" rx="33.3752" ry="33.3752"/><text text-anchor="middle" x="105" y="-100.987" font-family="Times,serif" font-size="14.00">(ab, b)</text></g><!-- 1&#45;&gt;3 --><g id="edge3" class="edge"><title>1&#45;&gt;3</title><path fill="none" stroke="black" d="M103.683,-174.333C103.842,-166.092 104.013,-157.232 104.178,-148.716"/><polygon fill="black" stroke="black" points="107.68,-148.629 104.374,-138.563 100.681,-148.493 107.68,-148.629"/></g><!-- 4 --><g id="node5" class="node"><title>4</title><polygon fill="none" stroke="black" points="96,-36 42,-36 42,-0 96,-0 96,-36"/><text text-anchor="middle" x="69" y="-13.8" font-family="Times,serif" font-size="14.00">aa</text></g><!-- 3&#45;&gt;4 --><g id="edge4" class="edge"><title>3&#45;&gt;4</title><path fill="none" stroke="black" stroke-dasharray="5,2" d="M92.4089,-74.3928C88.4779,-65.0907 84.1675,-54.8909 80.3286,-45.8069"/><polygon fill="black" stroke="black" points="83.505,-44.3319 76.3883,-36.4831 77.0571,-47.0568 83.505,-44.3319"/></g><!-- 5 --><g id="node6" class="node"><title>5</title><polygon fill="none" stroke="black" points="168,-36 114,-36 114,-0 168,-0 168,-36"/><text text-anchor="middle" x="141" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 3&#45;&gt;5 --><g id="edge5" class="edge"><title>3&#45;&gt;5</title><path fill="none" stroke="black" d="M117.591,-74.3928C121.522,-65.0907 125.833,-54.8909 129.671,-45.8069"/><polygon fill="black" stroke="black" points="132.943,-47.0568 133.612,-36.4831 126.495,-44.3319 132.943,-47.0568"/></g><!-- 7 --><g id="node8" class="node"><title>7</title><polygon fill="none" stroke="black" points="214,-123.187 160,-123.187 160,-87.1871 214,-87.1871 214,-123.187"/><text text-anchor="middle" x="187" y="-100.987" font-family="Times,serif" font-size="14.00">ab</text></g><!-- 6&#45;&gt;7 --><g id="edge7" class="edge"><title>6&#45;&gt;7</title><path fill="none" stroke="black" stroke-dasharray="5,2" d="M188.395,-178.326C188.119,-164.06 187.795,-147.327 187.529,-133.57"/><polygon fill="black" stroke="black" points="191.023,-133.209 187.33,-123.279 184.024,-133.345 191.023,-133.209"/></g><!-- 8 --><g id="node9" class="node"><title>8</title><polygon fill="none" stroke="black" points="286,-123.187 232,-123.187 232,-87.1871 286,-87.1871 286,-123.187"/><text text-anchor="middle" x="259" y="-100.987" font-family="Times,serif" font-size="14.00">a</text></g><!-- 6&#45;&gt;8 --><g id="edge8" class="edge"><title>6&#45;&gt;8</title><path fill="none" stroke="black" d="M206.664,-183.541C217.363,-167.728 230.953,-147.642 241.603,-131.9"/><polygon fill="black" stroke="black" points="244.785,-133.443 247.49,-123.199 238.987,-129.52 244.785,-133.443"/></g></g></svg><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="62pt" height="44pt" viewBox="0.00 0.00 62.00 44.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 40)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-40 58,-40 58,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><polygon fill="none" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g></g></svg><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="206pt" height="130pt" viewBox="0.00 0.00 206.00 130.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 126)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-126 202,-126 202,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="99" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="99" y="-101.044" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><polygon fill="lightgrey" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">b</text></g><!-- 0&#45;&gt;1 --><g id="edge1" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M85.871,-91.5579C78.612,-84.97 69.6152,-76.3607 62.3311,-68 56.0919,-60.8387 49.8455,-52.612 44.3778,-44.97"/><polygon fill="black" stroke="black" points="46.9618,-42.5573 38.3641,-36.3662 41.2244,-46.5676 46.9618,-42.5573"/><text text-anchor="middle" x="79.3345" y="-56.8" font-family="Times,serif" font-size="14.00">(3, A)</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><polygon fill="none" stroke="black" points="126,-36 72,-36 72,-0 126,-0 126,-36"/><text text-anchor="middle" x="99" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 0&#45;&gt;2 --><g id="edge2" class="edge"><title>0&#45;&gt;2</title><path fill="none" stroke="black" d="M99,-85.5951C99,-74.2572 99,-59.2271 99,-46.3153"/><polygon fill="black" stroke="black" points="102.5,-46.0951 99,-36.0952 95.5001,-46.0952 102.5,-46.0951"/><text text-anchor="middle" x="115.331" y="-56.8" font-family="Times,serif" font-size="14.00">(3, B)</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><polygon fill="none" stroke="black" points="198,-36 144,-36 144,-0 198,-0 198,-36"/><text text-anchor="middle" x="171" y="-13.8" font-family="Times,serif" font-size="14.00">ba</text></g><!-- 0&#45;&gt;3 --><g id="edge3" class="edge"><title>0&#45;&gt;3</title><path fill="none" stroke="black" d="M112.272,-91.5884C119.604,-85.0101 128.681,-76.4002 136,-68 142.219,-60.8617 148.418,-52.6417 153.833,-44.9987"/><polygon fill="black" stroke="black" points="156.976,-46.607 159.784,-36.3909 151.218,-42.6264 156.976,-46.607"/><text text-anchor="middle" x="163.331" y="-56.8" font-family="Times,serif" font-size="14.00">(2, C)</text></g></g></svg><?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: BST Pages: 1 --><svg width="206pt" height="130pt" viewBox="0.00 0.00 206.00 130.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 126)"><title>BST</title><polygon fill="white" stroke="none" points="-4,4 -4,-126 202,-126 202,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="99" cy="-104" rx="18" ry="18"/><text text-anchor="middle" x="99" y="-101.044" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 1 --><g id="node2" class="node"><title>1</title><polygon fill="lightgrey" stroke="black" points="54,-36 0,-36 0,-0 54,-0 54,-36"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">a</text></g><!-- 0&#45;&gt;1 --><g id="edge1" class="edge"><title>0&#45;&gt;1</title><path fill="none" stroke="black" d="M85.871,-91.5579C78.612,-84.97 69.6152,-76.3607 62.3311,-68 56.0919,-60.8387 49.8455,-52.612 44.3778,-44.97"/><polygon fill="black" stroke="black" points="46.9618,-42.5573 38.3641,-36.3662 41.2244,-46.5676 46.9618,-42.5573"/><text text-anchor="middle" x="79.3345" y="-56.8" font-family="Times,serif" font-size="14.00">(4, A)</text></g><!-- 2 --><g id="node3" class="node"><title>2</title><polygon fill="none" stroke="black" points="126,-36 72,-36 72,-0 126,-0 126,-36"/><text text-anchor="middle" x="99" y="-13.8" font-family="Times,serif" font-size="14.00">ab</text></g><!-- 0&#45;&gt;2 --><g id="edge2" class="edge"><title>0&#45;&gt;2</title><path fill="none" stroke="black" d="M99,-85.5951C99,-74.2572 99,-59.2271 99,-46.3153"/><polygon fill="black" stroke="black" points="102.5,-46.0951 99,-36.0952 95.5001,-46.0952 102.5,-46.0951"/><text text-anchor="middle" x="115.331" y="-56.8" font-family="Times,serif" font-size="14.00">(2, C)</text></g><!-- 3 --><g id="node4" class="node"><title>3</title><polygon fill="none" stroke="black" points="198,-36 144,-36 144,-0 198,-0 198,-36"/><text text-anchor="middle" x="171" y="-15.0441" font-family="Times,serif" font-size="14.00">ϵ</text></g><!-- 0&#45;&gt;3 --><g id="edge3" class="edge"><title>0&#45;&gt;3</title><path fill="none" stroke="black" d="M112.272,-91.5884C119.604,-85.0101 128.681,-76.4002 136,-68 142.219,-60.8617 148.418,-52.6417 153.833,-44.9987"/><polygon fill="black" stroke="black" points="156.976,-46.607 159.784,-36.3909 151.218,-42.6264 156.976,-46.607"/><text text-anchor="middle" x="163.331" y="-56.8" font-family="Times,serif" font-size="14.00">(4, B)</text></g></g></svg>

""")

// %%
import com.twosigma.beakerx.widget.IntSlider
import com.twosigma.beakerx.widget.IntProgress

slider = new IntSlider()
progress = new IntProgress()

def mapList = [
   [a:1, b:2, c:3],
   [a:4, b:5, c:6],
   [a:7, b:8, c:5]
]
table1 = new TableDisplay(mapList)
OutputCell.HIDDEN

// %%
import com.twosigma.beakerx.table.*
import com.twosigma.beakerx.table.format.TableDisplayStringFormat
display = new TableDisplay(new CSV().read("/Users/lijianlin/Downloads/interest-rates.csv"))
//show all time columns in days
display.setStringFormatForTimes(TimeUnit.DAYS)
//min 4, max 6 decimal places for all doubles
display.setStringFormatForType(ColumnType.Double, TableDisplayStringFormat.getDecimalFormat(4,6))
//setting for a column takes precidence over the type
display.setStringFormatForColumn("m3", TableDisplayStringFormat.getDecimalFormat(0, 0))
//set the alignment
display.setAlignmentProviderForType(ColumnType.Double, TableDisplayAlignmentProvider.RIGHT_ALIGNMENT)
display.setAlignmentProviderForColumn('m3', TableDisplayAlignmentProvider.CENTER_ALIGNMENT)

//using a closure
display.setStringFormatForColumn("y3") { value, row, col, tableDisplay ->
   if(value < 8) {
       ":("
   } else {
       ":)"
  } 
}

display

// %%
import com.twosigma.beakerx.widget.*


def mapList = [
   [a:1, b:2, c:3],
   [a:4, b:5, c:6],
   [a:7, b:8, c:5]
]
table1 = new TableDisplay(mapList)

// %%
HTML("""
<table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
  <tr>
    <th></th>
    <th> (ϵ, ϵ)</th>
    <th> (ϵ, b)</th>
  </tr>
      <tr>
  <th align="left" colspan="3" bgcolor="gray"></th>
</tr>
  <tr>
    <td>ϵ</td>
    <td>-</td>
    <td>-</td>
  </tr>
    <tr>
    <td>a</td>
    <td>-</td>
    <td>+</td>
    </tr>
    <tr>
  <th colspan="3" bgcolor="gray"></th>
</tr>
        <tr>
    <td>b</td>
    <td>-</td>
    <td>-</td>
    </tr>
        <tr>
    <td>aa</td>
    <td>-</td>
    <td>-</td>
    </tr>
        <tr>
    <td>ab</td>
    <td>-</td>
    <td>+</td>
    </tr>
</table>
""")
// Out:
// <table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
// <tr>
// <th></th>
// <th> (ϵ, ϵ)</th>
// <th> (ϵ, b)</th>
// </tr>
// <tr>
// <th align="left" colspan="3" bgcolor="gray"></th>
// </tr>
// <tr>
// <td>ϵ</td>
// <td>-</td>
// <td>-</td>
// </tr>
// <tr>
// <td>a</td>
// <td>-</td>
// <td>+</td>
// </tr>
// <tr>
// <th colspan="3" bgcolor="gray"></th>
// </tr>
// <tr>
// <td>b</td>
// <td>-</td>
// <td>-</td>
// </tr>
// <tr>
// <td>aa</td>
// <td>-</td>
// <td>-</td>
// </tr>
// <tr>
// <td>ab</td>
// <td>-</td>
// <td>+</td>
// </tr>
// </table>

// %%
Learner.getLearnerFDFA().getHypothesis()

// %%
HTML("""
<table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
  <tr>
    <th> Preivous</th>
    <th> Current</th>

</tr>
  <tr>
    <td>-</td>
    <td>-</td>
  </tr>

</table>
""")
// Out:
// <table border="1" cellspacing="0" bordercolor="#000000"  style="border-collapse:collapse;">
// <tr>
// <th> Preivous</th>
// <th> Current</th>
//
// </tr>
// <tr>
// ...

// %%
import roll.main.*
import com.google.common.collect.ImmutableList;
import org.apache.commons.lang3.tuple.Triple;
import org.junit.Test;
import roll.automata.DFA;
import roll.automata.NBA;
import roll.learner.LearnerBase;
import roll.learner.LearnerDFA;
import roll.learner.nba.lomega.LearnerNBALOmega;
import roll.main.LearningSequence;
import roll.main.Options;
import roll.oracle.nba.rabit.TeacherNBARABIT;
import roll.parser.Format;
import roll.parser.Parser;
import roll.parser.UtilParser;
import roll.query.CE;
import roll.query.Query;
import roll.query.QuerySimple;
import roll.table.HashableValue;
import roll.words.Alphabet;
import roll.words.Word;

import java.util.ArrayList;
import java.util.Iterator;
import java.util.Optional;
import java.util.function.Function;

Function<Query<HashableValue>,Boolean> memberAnswer = {querySimple -> return true}
l = new SemiLearning(alphabet,options,memberAnswer)
// Out:
// roll.main.SemiLearning@f8abae6

// %%
l.getHypothesis()
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="103pt" height="117pt" viewBox="0.00 0.00 103.00 117.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 113)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-113 99,-113 99,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="27" cy="-18" rx="18" ry="18"/><text text-anchor="middle" x="27" y="-13.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M44.7817,-21.2357C54.3149,-21.7856 63,-20.707 63,-18 63,-16.3504 59.7749,-15.3055 55.0981,-14.8653"/><poly
// ...

// %%
import roll.query.CE
l.refineHypothesis(CE.withAlphabet(alphabet).omega("a","a"))
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.38.0 (20140413.2041) --><!-- Title: %3 Pages: 1 --><svg width="181pt" height="297pt" viewBox="0.00 0.00 181.07 297.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 293)"><title>%3</title><polygon fill="white" stroke="none" points="-4,4 -4,-293 177.068,-293 177.068,4 -4,4"/><!-- 0 --><g id="node1" class="node"><title>0</title><ellipse fill="none" stroke="black" cx="105.068" cy="-198" rx="18" ry="18"/><text text-anchor="middle" x="105.068" y="-193.8" font-family="Times,serif" font-size="14.00">0</text></g><!-- 0&#45;&gt;0 --><g id="edge1" class="edge"><title>0&#45;&gt;0</title><path fill="none" stroke="black" d="M122.85,-201.236C132.383,-201.786 141.068,-200.707 141.068,-198 141.068,-196.35 137.
// ...

// %%
import roll.query.CE
l.refineHypothesis(CE.withAlphabet(alphabet).omega("b","b"))
// Out:
// java.lang.NullPointerException
// 	at roll.learner.nba.lomega.translator.TranslatorFDFA.getQuery(TranslatorFDFA.java:91)
// 	at roll.learner.nba.lomega.translator.TranslatorFDFAUnder.translate(TranslatorFDFAUnder.java:41)
// 	at roll.learner.nba.lomega.LearnerNBALOmega.refineHypothesis(LearnerNBALOmega.java:97)
// 	at roll.main.SemiLearning.refineHypothesis(SemiLearning.java:25)
// 	at roll.main.SemiLearning$refineHypothesis$0.call(Unknown Source)
// 	at script1524118601647687023483.run(script1524118601647687023483.groovy:2)
// 	at com.twosigma.beakerx.groovy.evaluator.GroovyCodeRunner.call(GroovyCodeRunner.java:72)
// 	at com.twosigma.beakerx.groovy.evaluator.GroovyCodeRunner.call(GroovyCodeRunner.java:36)
